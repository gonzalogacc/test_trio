# %%
using BioSequences
using Pseudoseq

# %%
## Create some PE for all
Pseudoseq.sequence("./p1/p1-yeast-chr45.fasta", "./p1/p1-pe-reads.fastq", ng=5000, flen=700, cov=70, paired = true, rdlen = 250, err = 0.001)
Pseudoseq.sequence("./p1/p1-yeast-chr45.fasta", "./p1/p1-long-reads.fastq", ng = 5000, flen = 40000, cov = 30, rdlen = nothing, err = 0.1, paired = false)
Pseudoseq.sequence("./p1/p1-yeast-chr45.fasta", "./p1/p1-link-reads.fastq", ng = 5000, tusize = 1000000, taggedflen = 40000, flen = 700, cov = 50, rdlen = 250, err = 0.1)

Pseudoseq.sequence("./p2/p2-yeast-chr45.fasta", "./p2/p2-pe-reads.fastq", ng=5000, flen=700, cov=70, paired = true, rdlen = 250, err = 0.001)
Pseudoseq.sequence("./p2/p2-yeast-chr45.fasta", "./p2/p2-long-reads.fastq", ng = 5000, flen = 40000, cov = 30, rdlen = nothing, err = 0.1, paired = false)
Pseudoseq.sequence("./p2/p2-yeast-chr45.fasta", "./p2/p2-link-reads.fastq", ng = 5000, tusize = 1000000, taggedflen = 40000, flen = 700, cov = 50, rdlen = 250, err = 0.1)

Pseudoseq.sequence("./child/child-yeast-chr45.fasta", "./child/child-pe-reads.fastq", ng=5000, flen=700, cov=70, paired = true, rdlen = 250, err = 0.001)
Pseudoseq.sequence("./child/child-yeast-chr45.fasta", "./child/child-long-reads.fastq", ng = 5000, flen = 40000, cov = 30, rdlen = nothing, err = 0.1, paired = false)
Pseudoseq.sequence("./child/child-yeast-chr45.fasta", "./child/child-link-reads.fastq", ng = 5000, tusize = 1000000, taggedflen = 40000, flen = 700, cov = 50, rdlen = 250, err = 0.1)
# Out:
# ┌ Info: - ✔ Created pool of 5000 copies of a 4217614bp genome
# └ @ Pseudoseq /Users/ggarcia/.julia/packages/Pseudoseq/72NPA/src/sequence.jl:45
# ┌ Info: - ✔ Created pool of fragments with an average length of 700bp
# └ @ Pseudoseq /Users/ggarcia/.julia/packages/Pseudoseq/72NPA/src/sequence.jl:55
# ┌ Info: - ✔ Subsampled pool at 70X coverage (590465 molecules)
# └ @ Pseudoseq /Users/ggarcia/.julia/packages/Pseudoseq/72NPA/src/sequence.jl:62
# ┌ Info: - ✔ Created set of 250bp paired-end reads
# └ @ Pseudoseq /Users/ggarcia/.julia/packages/Pseudoseq/72NPA/src/sequence.jl:66
# ┌ Info: - ✔ Applied sequencing errors at a per-base rate of 0.001
# └ @ Pseudoseq /Users/ggarcia/.julia/packages/Pseudoseq/72NPA/src/sequence.jl:73
# ┌ Info: - ✔ Wrote 825306 paired end reads to FASTQ file
# └ @ Pseudoseq /Users/ggarcia/.julia/packages/Pseudoseq/72NPA/src/reads.jl:214
# ┌ Info: - ✔ Created pool of 5000 copies of a 4217614bp genome
# ...
